# %%
class Gauss:
    def __init__(self):
        print("输入矩阵的行数：")
        self.n = int(input())
        print("输入矩阵的列数：")
        self.m = int(input())
        print("依次输入矩阵的每一行，一行以空格隔开每个数")
        self.matrix = [[0]*self.m]*self.n
        for i in range(self.n):
            self.matrix[i] = input().split(" ")
            for j in range(self.m):
                self.matrix[i][j] = int(self.matrix[i][j])

# %%
import numpy as np
from sympy import Matrix

opr=Gauss()
print(Matrix(opr.matrix).rref())
# Out:
# 输入矩阵的行数：
# 4
# 输入矩阵的列数：
# 5
# 依次输入矩阵的每一行，一行以空格隔开每个数
# 2 -1 4 -3 -4
# 1 0 1 -1 -3
# 3 1 1 0 1
# 7 0 7 -3 3
# (Matrix([
# [1, 0,  1, 0,  3],
# [0, 1, -2, 0, -8],
# [0, 0,  0, 1,  6],
# [0, 0,  0, 0,  0]]), (0, 1, 3))
